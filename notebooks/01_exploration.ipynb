# %% [markdown]
# # Data Extraction
#
# In this notebook, we will extract the different tables characterizing poverty rate data by region in Tunisia. The source is the PDF report from the National Institute of Statistics in collaboration with the World Bank (2020), available at: [link](https://ins.tn/sites/default/files/publicationS/pdf/Carte%20de%20la%20pauvreté%20en%20Tunisie_final_0.pdf).
#
# All code in this notebook serves as **parsers**, generating intermediate CSV files for each required table. The subsequent notebook, `02_cleaning.ipynb`, will perform cleaning operations on these extracted data.

# %% [markdown]
# ## 1. Extracting All Tables from the PDF Report

# %%
import camelot
import os

pdf_path = "../data/raw/ins_tunisia_report_2020.pdf"

tables = camelot.read_pdf(pdf_path, pages='all', flavor='stream')

print(f"Found {len(tables)} tables in the PDF.")
# Out:
# /Users/mohamedriahi/miniconda3/envs/tunisia/lib/python3.10/site-packages/camelot/parsers/base.py:238: UserWarning: No tables found in table area (0, 0, 612.0, 792.0)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# /Users/mohamedriahi/miniconda3/envs/tunisia/lib/python3.10/site-packages/camelot/parsers/base.py:238: UserWarning: No tables found in table area (0, 0, 612.0, 792.0)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# /Users/mohamedriahi/miniconda3/envs/tunisia/lib/python3.10/site-packages/camelot/parsers/base.py:238: UserWarning: No tables found in table area (0, 0, 612.0, 792.0)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# /Users/mohamedriahi/miniconda3/envs/tunisia/lib/python3.10/site-packages/camelot/parsers/base.py:238: UserWarning: No tables found in table area (35.0, 65.6, 567.97504, 746.675135135135)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# /Users/mohamedriahi/miniconda3/envs/tunisia/lib/python3.10/site-packages/camelot/parsers/base.py:238: UserWarning: No tables found in table area (35.0, 88.39999999999999, 567.97504, 788.9254054054052)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# /Users/mohamedriahi/miniconda3/envs/tunisia/lib/python3.10/site-packages/camelot/parsers/base.py:238: UserWarning: No tables found in table area (106.844214166872, 462.76438162549965, 470.69807562408033, 752.7602851058676)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# /Users/mohamedriahi/miniconda3/envs/tunisia/lib/python3.10/site-packages/camelot/parsers/base.py:238: UserWarning: No tables found in table area (65.168, 542.94, 94.29100000000001, 766.0314634146341)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# /Users/mohamedriahi/miniconda3/envs/tunisia/lib/python3.10/site-packages/camelot/parsers/base.py:238: UserWarning: No tables found in table area (0, 0, 612.0, 792.0)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 6
#       2 import os
#       4 pdf_path = "../data/raw/ins_tunisia_report_2020.pdf"
# ----> 6 tables = camelot.read_pdf(pdf_path, pages='all', flavor='stream')
#       8 print(f"Found {len(tables)} tables in the PDF.")
#
# File ~/miniconda3/envs/tunisia/lib/python3.10/site-packages/camelot/io.py:134, in read_pdf(filepath, pages, password, flavor, suppress_stdout, parallel, layout_kwargs, debug, **kwargs)
#     132 p = PDFHandler(filepath, pages=pages, password=password, debug=debug)
#     133 kwargs = remove_extra(kwargs, flavor=flavor)
# --> 134 tables = p.parse(
#     135     flavor=flavor,
#     136     suppress_stdout=suppress_stdout,
#     137     parallel=parallel,
#     138     layout_kwargs=layout_kwargs,
#     139     **kwargs,
#     140 )
#     141 return tables
#
# File ~/miniconda3/envs/tunisia/lib/python3.10/site-packages/camelot/handlers.py:257, in PDFHandler.parse(self, flavor, suppress_stdout, parallel, layout_kwargs, **kwargs)
#     255     else:
#     256         for p in self.pages:
# --> 257             t = self._parse_page(
#     258                 p, tempdir, parser, suppress_stdout, layout_kwargs
#     259             )
#     260             tables.extend(t)
#     262 return TableList(sorted(tables))
#
# File ~/miniconda3/envs/tunisia/lib/python3.10/site-packages/camelot/handlers.py:288, in PDFHandler._parse_page(self, page, tempdir, parser, suppress_stdout, layout_kwargs)
#     264 def _parse_page(
#     265     self, page: int, tempdir: str, parser, suppress_stdout: bool, layout_kwargs
#     266 ):
#     267     """Extract tables by calling parser.get_tables on a single page PDF.
#     268
#     269     Parameters
#    (...)
#     285
#     286     """
#     287     layout, dimensions, images, chars, horizontal_text, vertical_text = (
# --> 288         self._save_page(self.filepath, page, tempdir, **layout_kwargs)
#     289     )
#     290     page_path = os.path.join(tempdir, f"page-{page}.pdf")
#     291     parser.prepare_page_parse(
#     292         page_path,
#     293         layout,
#    (...)
#     299         layout_kwargs=layout_kwargs,
#     300     )
#
# File ~/miniconda3/envs/tunisia/lib/python3.10/site-packages/camelot/handlers.py:158, in PDFHandler._save_page(self, filepath, page, temp, **layout_kwargs)
#     124 def _save_page(
#     125     self, filepath: StrByteType | Path, page: int, temp: str, **layout_kwargs
#     126 ) -> tuple[
#    (...)
#     132     list[LTTextLineVertical],
#     133 ]:
#     134     """Saves specified page from PDF into a temporary directory.
#     135
#     136     Parameters
#    (...)
#     156
#     157     """
# --> 158     infile = PdfReader(filepath, strict=False)
#     159     if infile.is_encrypted:
#     160         infile.decrypt(self.password)
#
# File ~/miniconda3/envs/tunisia/lib/python3.10/site-packages/pypdf/_reader.py:332, in PdfReader.__init__(self, stream, strict, password)
#     330     with open(stream, "rb") as fh:
#     331         stream = BytesIO(fh.read())
# --> 332 self.read(stream)
#     333 self.stream = stream
#     335 self._override_encryption = False
#
# File ~/miniconda3/envs/tunisia/lib/python3.10/site-packages/pypdf/_reader.py:1572, in PdfReader.read(self, stream)
#    1569     logger_warning(f"incorrect startxref pointer({xref_issue_nr})", __name__)
#    1571 # read all cross reference tables and their trailers
# -> 1572 self._read_xref_tables_and_trailers(stream, startxref, xref_issue_nr)
#    1574 # if not zero-indexed, verify that the table is correct; change it if necessary
#    1575 if self.xref_index and not self.strict:
#
# File ~/miniconda3/envs/tunisia/lib/python3.10/site-packages/pypdf/_reader.py:1782, in PdfReader._read_xref_tables_and_trailers(self, stream, startxref, xref_issue_nr)
#    1780     x = stream.read(1)
#    1781 if x == b"x":
# -> 1782     startxref = self._read_xref(stream)
#    1783 elif xref_issue_nr:
#    1784     try:
#
# File ~/miniconda3/envs/tunisia/lib/python3.10/site-packages/pypdf/_reader.py:1829, in PdfReader._read_xref(self, stream)
#    1827 stream.seek(cast(int, new_trailer["/XRefStm"]) + 1, 0)
#    1828 try:
# -> 1829     self._read_pdf15_xref_stream(stream)
#    1830 except Exception:
#    1831     logger_warning(
#    1832         f"XRef object at {new_trailer['/XRefStm']} can not be read, some object may be missing",
#    1833         __name__,
#    1834     )
#
# File ~/miniconda3/envs/tunisia/lib/python3.10/site-packages/pypdf/_reader.py:1920, in PdfReader._read_pdf15_xref_stream(self, stream)
#    1917     return num in self.xref.get(generation, []) or num in self.xref_objStm  # type: ignore
#    1919 # Iterate through each subsection
# -> 1920 self._read_xref_subsections(idx_pairs, get_entry, used_before)
#    1921 return xrefstream
#
# File ~/miniconda3/envs/tunisia/lib/python3.10/site-packages/pypdf/_reader.py:-1, in PdfReader._read_xref_subsections(self, idx_pairs, get_entry, used_before)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2. Review Tables Before Saving

# %%
for i, table in enumerate(tables):
    print(f"Table {i}:")
    print(table.df.head(), "\n")
# Out:
# Table 0:
#                                  0
# 0  Carte de la pauvreté en Tunisie
# 1                   Septembre 2020
#
# Table 1:
#    0                     1
# 0     CARTE DE LA PAUVRETE
# 1  1
#
# Table 2:
#    0                     1
# 0     CARTE DE LA PAUVRETE
# 1  2
#
# Table 3:
#                                                    0
# 0                                 Table des matières
# 1  Résumé ..........................................
# 2  National ........................................
# 3  Introduction ....................................
# 4  Méthodologie et enjeux ..........................
#
# Table 4:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1  Délégations du gouvernorat de Nabeul ............
# 2  Délégations du gouvernorat de Zaghouan ..........
# 3  Délégations du gouvernorat de Bizerte ...........
# 4  Nord-Ouest : Beja, Jendouba, Kef et Seliana .....
#
# Table 5:
#                                                    0 1 2 3  \
# 0
# 1                                            Résumé1
# 2  Le  présent  rapport  sur  la  carte  de  la  ...
# 3  Tunisie, en collaboration avec la Banque Mondi...
# 4  calculés sur la base des données du Recensemen...
#
#                       4
# 0  CARTE DE LA PAUVRETE
# 1
# 2
# 3
# 4
#
# Table 6:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1  délégations les plus pauvres sont Neber (45,4 ...
# 2  de  Jendouba  Sud  (10,7 %),  Bou  Salem  (16,...
# 3              pauvreté la plus faible de la région.
# 4                                         Centre-Est
#
# Table 7:
#                                0              1  2          3           4   \
# 0
# 1
# 2                                  ّرقفلاّتارشؤم  ّ  باستحا\nّ          مت
# 3  ّىوتسموّكلاهتسلااوّقافنلإاّلوح
# 4                           ّحيتت        (E.L.L)  ّ             P. Lanjouw
#
#          5                 6           7            8  9          10  \
# 0
# 1
# 2  ّدقو\n،ّ  ةيسنوتلا دلابلاب              رقفلا ةطيرخ
# 3              ّينطولاّحسملاو           ّ         2014        ّ\nةنس
# 4                       ّو\nّ  J. Lanjouw        ّو\nّ     C. Elbers
#
#          11               12                                     13  \
# 0
# 1
# 2   ب صاخلا                   ّريرقتلاّاذهّيلودلاّكنبلاّعمّنواعتلاب
# 3  ّل\nىنكس                                               لاوّناكسل
# 4            ّاهروطّيتلاّباس
#
#                     14          15            16                     17  \
# 0                                                  CARTE DE LA PAUVRETE
# 1
# 2                                              ّ  ءاصحلإلّينطولاّدهعملا
# 3  لّماعلا\nّدادعت\nلا     ّتانايب  ّةدعاق\nّىلع                     اّ
# 4                   حت  لإاّةيجهنم   ّنأوّاملعّ،            2015\nّةنسل
#
#                         18
# 0
# 1                     صخلم
# 2                 ّ\nّ دعأ
# 3  ءانبّريرقتلاّيفّةدراولا
# 4                رسلأاّشيع
#
# Table 8:
#                                             0                 1  \
# 0
# 1
# 2  25.8\nّتايدمتعملاّ دعتو\n٪.ّ\nّ\nةهجلاب\nّ  رقفلاّلدعمّطسوتم
# 3        لمّ\nاسوب\n٪ّ)و\n10.7\nّ(\nةبودنج\nّ          تايدمتعم
# 4
#
#                                                    2
# 0                               CARTE DE LA PAUVRETE
# 1                          يبرغلا لامشلا\n ىوتسم ىلع
# 2  ّغلبّدقو\n.ّ\nةنايل\nّوس\nفاكلا\nّو\nةبودنج\nو...
# 3  ّدعتّنيحّيف\n٪)ّ.\n39.7\nّ(\nفسوي يديس\n \nةيق...
# 4  .ارقفّلقلأاّ)\n٪\n16.7\nّ(\nةقربط\nوّ)٪\n16.8\...
#
# Table 9:
#                                                    0                     1
# 0                                                     CARTE DE LA PAUVRETE
# 1                                            Summary
# 2  This poverty map report has been produced by t...
# 3  World Bank. The poverty indicators presented i...
# 4  Census  of  Population  and  Housing  (RGPH)  ...
#
# Table 10:
#                                                    0                     1
# 0                                                     CARTE DE LA PAUVRETE
# 1  delegations are Ouled Chamekh (35%) and Hebira...
# 2  Sfax Ville ( 2.5%) among those with the lowest...
# 3                                        Center-West
# 4  The Center-West is made up of three governorat...
#
# Table 11:
#                                                    0  \
# 0
# 1                                       Introduction
# 2  Dès  l’obtention  de  son  indépendance  en  1...
# 3  essentiellement sur les trois piliers suivants4 :
# 4                                                  
#
#                                                    1
# 0                               CARTE DE LA PAUVRETE
# 1
# 2
# 3
# 4  L’accès gratuit à l’éducation pour tous les en...
#
# Table 12:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1  consommation du recensement des ménages sur la...
# 2  des  ménages,  en  appliquant  aux  mêmes  var...
# 3  l’enquête ménages. Les statistiques sur la pau...
# 4  à  l'aide  des  estimations  de  la  consommat...
#
# Table 13:
#                                                    0         1        2  \
# 0
# 1  Tableau 1. Structure administrative de la Tunisie
# 2                                              Unité    Nombre
# 3                                     administrative  d’unités
# 4                                                               Médiane
#
#                    3        4        5                   6  \
# 0
# 1
# 2  Nombre de ménages                    Nombre d’individus
# 3
# 4            Minimum  Maximum  Médiane             Minimum
#
#                       7
# 0  CARTE DE LA PAUVRETE
# 1
# 2
# 3
# 4               Maximum
#
# Table 14:
#                                                    0           1  \
# 0
# 1  Tableau 2. Taux de pauvreté par zone résidenti...
# 2                                 Milieu résidentiel  Population
# 3                                    Grandes villes7   3 810 734
# 4                        Petite et moyenne communes8   3 143 090
#
#                       2
# 0  CARTE DE LA PAUVRETE
# 1
# 2      Taux de pauvreté
# 3                 6,3 %
# 4                15,0 %
#
# Table 15:
#                                                    0  \
# 0  La consommation des ménages observée dans l’en...
# 1                                             suit :
# 2
# 3
# 4                                               Où :
#
#                                                    1
# 0
# 1
# 2
# 3                         (1) \n𝑙𝑛(𝑦𝑐ℎ) = 𝑋𝑐ℎ𝛽 + 𝜖𝑐ℎ
# 4  𝑙𝑛(𝑦𝑐ℎ) est le logarithme népérien de 𝑦𝑐ℎ la d...
#
# Table 16:
#                                                    0 1                     2
# 0                                                       CARTE DE LA PAUVRETE
# 1  et Rao (2010) combine l'approche basée sur la ...
# 2  distribution observée de l'erreur de localisat...
# 3  de distribution des erreurs sont estimées de m...
# 4  L'estimation a été réalisée à l'aide du progra...
#
# Table 17:
#                                                    0
# 0  Tableau 3. Test-T sur la taille du ménage sign...
# 1             Two-sample t test with equal variances
# 2  Group       Obs        Mean    Std. Err.   Std...
# 3  census   522,889    3.988227    .0024214    1....
# 4  survey    25,049    4.181684    .0113629    1....
#
# Table 18:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1               Estimations de la pauvreté nationale
# 2  Globalement, il existe des différences signifi...
# 3  les grandes villes (voir tableau 2 ci-dessus)....
# 4  pas  en  mesure  de  refléter  ces  différence...
#
# Table 19:
#         0         1            2                             3             4  \
# 0                                                   EBCNV 2015
# 1  Région                         95 % intervalle de confiance
# 2           Taux de
# 3                    Erreur type
# 4          pauvreté                                 Niveau bas  Niveau élevé
#
#           5            6           7
# 0              RGPH 2014
# 1
# 2   Taux de
# 3            Erreur type  Différence
# 4  pauvreté
#
# Table 20:
#                   0   1
# 0                    35
# 1                    30
# 2                    25
# 3  Taux de pauvreté  20
# 4                    15
#
# Table 21:
#            0         1       2           3     4             5         6  \
# 0             pauvreté    type              95 %                pauvreté
# 1                               Niveau bas        Niveau élevé
# 2      TUNIS       3,5  0,5748         2,4                 4,6       4,6
# 3     ARIANA       5,4  0,6976         4,0                 6,8       7,0
# 4  BEN AROUS       4,3  0,5946         3,1                 5,4       5,6
#
#         7        8
# 0    type  Absolue
# 1
# 2  0,3601      1,1
# 3  1,0237      1,6
# 4  0,2877      1,4
#
# Table 22:
#     0                     1
# 0      CARTE DE LA PAUVRETE
# 1  20
#
# Table 23:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1                     Carte de la pauvreté nationale
# 2  Selon les économistes (Helpman et Krugman, 198...
# 3  économies  d’agglomération  ont  trois  source...
# 4  fournisseurs spécialisés notamment dans les bi...
#
# Table 24:
#                                                    0  \
# 0
# 1                        Figure 4. Carte de pauvreté
# 2  Source : Calcul des auteurs basé sur l'EBCNV 2...
# 3                                                 22
#
#                                        1
# 0                   CARTE DE LA PAUVRETE
# 1  Figure 5. Nombre de personnes pauvres
# 2
# 3
#
# Table 25:
#                                                    0                     1
# 0                                                     CARTE DE LA PAUVRETE
# 1                   Profil de la pauvreté en Tunisie
# 2  L’analyse du profil de la pauvreté consiste à ...
# 3  variables classées en deux groupes : variables...
# 4  En général, la pauvreté est définie suivant de...
#
# Table 26:
#                                                    0                     1
# 0                                                     CARTE DE LA PAUVRETE
# 1  En observant la carte ci-après (voir figure 7)...
# 2           Figure 7. Taux d’urbanisation par région      Taux de pauvreté
# 3  Source : Calcul des auteurs à partir des donné...
# 4                                                 24
#
# Table 27:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1                        Pauvreté et taux de chômage
# 2  Les liens entre chômage et pauvreté sont compl...
# 3  souvent exposés au risque de pauvreté que les ...
# 4  les  ressources  monétaires  du  conjoint  et/...
#
# Table 28:
#                                                    0                     1
# 0                                                     CARTE DE LA PAUVRETE
# 1  La carte de la figure 9 ci-après indique que l...
# 2                           chômage les plus élevés.
# 3           Figure 9. Taux de chômage par délégation      Taux de pauvreté
# 4  Source : Calcul des auteurs à partir des donné...
#
# Table 29:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1                 Pauvreté et infrastructure de base
# 2  Les  études  (Craig,  D.,  Porter,  D.  2003, ...
# 3  pauvreté  exige  une  offre  suffisante  et  a...
# 4  effectuées  sur  plusieurs  pays  en  développ...
#
# Table 30:
#                                                    0  \
# 0
# 1  Les  cartes  de  la  figure  11  ci-après  ind...
# 2  caractérisées déjà par des taux de pauvreté él...
# 3           Figure 11. Infrastructure par délégation
# 4  a) Taux de raccordement aux réseaux d’eau potable
#
#                                                    1
# 0                               CARTE DE LA PAUVRETE
# 1
# 2
# 3
# 4  b) Taux de raccordement aux réseaux de gaz nat...
#
# Table 31:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1                       Pauvreté et type de logement
# 2  Le  logement  forme  l’une  des  dimensions  d...
# 3  ménage.  L’observation  de  la  carte  de  la ...
# 4                             logement rudimentaire.
#
# Table 32:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1         Pauvreté et accès aux commodités de la vie
# 2  Les  cartes  de  la  figure  13  ci-après  pré...
# 3  Il  s’agit  ici  de  la  télévision,  de  l’or...
# 4  que les délégations les plus pauvres sont cell...
#
# Table 33:
#                                                    0  \
# 0
# 1  Profil de la pauvreté selon les variables rela...
# 2                                              Parmi
# 3  l’éducation. Les études (Michaelowa, K. 2000 e...
# 4  également celles qui ont  les  enfants  les mo...
#
#                                       1                               2  \
# 0
# 1
# 2  les  aspects  multidimensionnels  de  la  pauvreté,  une  composante
# 3
# 4
#
#                             3                     4
# 0                              CARTE DE LA PAUVRETE
# 1
# 2  importante  est  celle  de            l’accès  à
# 3
# 4
#
# Table 34:
#                                                    0  \
# 0
# 1              Pauvreté et niveau de scolarisation14
# 2  Le  graphique  de  la  figure  15  ci-après  d...
# 3                   l’enseignement  supérieur.  Plus
# 4                                       la pauvreté.
#
#                                                    1                     2
# 0                                                     CARTE DE LA PAUVRETE
# 1
# 2
# 3  la  population  est  scolarisée,  moins  elle ...     le  phénomène  de
# 4
#
# Table 35:
#                                                    0                     1
# 0                                                     CARTE DE LA PAUVRETE
# 1                   Pauvreté et niveau d’instruction
# 2  Les  graphiques  de  la  figure  16  ci-après ...
# 3  d’instruction.  Il  est  clair  que  le  taux ...
# 4        (néant, primaire, secondaire et supérieur).
#
# Table 36:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1               Pauvreté et taux de préscolarisation
# 2  Le  graphique  de  la  figure  18  ci-après  i...
# 3  caractérisent par les taux de préscolarisation...
# 4  F\nigure 17  Taux de préscolarisation par délé...
#
# Table 37:
#                                                    0  \
# 0
# 1                Pauvreté et taux d’abandon scolaire
# 2  L’abandon scolaire est un phénomène dont les c...
# 3                    qui \nconstituent \nun \nrisque
# 4                  figures 19,  20  et  21  ci-après
#
#                                   1  \
# 0
# 1
# 2
# 3       important \nde \ndécrochage
# 4  indiquent  que  ce  sont  plutôt
#
#                                                    2
# 0                               CARTE DE LA PAUVRETE
# 1
# 2
# 3  scolaire. \nLes \ncartes \net \nles \ngraphiqu...
# 4  les  délégations  à  taux  de  pauvreté  élevé...
#
# Table 38:
#                                                    0  \
# 0
# 1  Figure 20. Relation entre le taux de pauvreté ...
# 2  Source : Calcul des auteurs à partir des donné...
# 3  Figure 21. Relation entre les taux de pauvreté...
# 4   a) Abandon scolaire au primaire et au secondaire
#
#                                                    1
# 0                               CARTE DE LA PAUVRETE
# 1
# 2
# 3
# 4  b) Abandon scolaire de la tranche d’âge de 6 à...
#
# Table 39:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1  Analyse de la pauvreté des délégations tunisie...
# 2  Grand Tunis : Tunis, Ariana, Ben Arous et Manouba
# 3  Le  grand  Tunis  est  constitué  de  quatre  ...
# 4  48 délégations. Il constitue la région la plus...
#
# Table 40:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1  Les  délégations  les  plus  riches  ayant  le...
# 2    Goulette, Cité El Khadra, Carthage et Bab Bhar.
# 3  Comme il a été démontré ci-dessus, il existe u...
# 4  cartes  de  la  figure  23  ci-après  indiquen...
#
# Table 41:
#                                                    0           1  \
# 0
# 1  Tableau 3. Taux d’abandon scolaire et taux de ...
# 2                                                        Abandon
# 3                                         Délégation
# 4                                                     primaire %
#
#               2                 3                     4
# 0                                  CARTE DE LA PAUVRETE
# 1
# 2       Abandon  Abandon primaire               Taux de
# 3
# 4  secondaire %   et secondaire %            pauvreté %
#
# Table 42:
#                                                    0 1  \
# 0
# 1  Figure 24. Relation entre le taux de pauvreté ...
# 2
# 3                                a) Taux de pauvreté
# 4
#
#                                                    2                     3 4
# 0                                                     CARTE DE LA PAUVRETE
# 1
# 2             b) Taux d’abandon scolaire au primaire
# 3
# 4  c) Taux d’abandon scolaire au primaire et au s...
#
# Table 43:
#                                                    0           1  \
# 0
# 1  Tableau 4. Taux d’abandon scolaire et taux de ...
# 2                                                        Abandon
# 3                                         Délégation
# 4                                                     primaire %
#
#               2                 3                     4
# 0                                  CARTE DE LA PAUVRETE
# 1
# 2       Abandon  Abandon primaire               Taux de
# 3
# 4  secondaire %   et secondaire %            pauvreté %
#
# Table 44:
#                                                    0 1  \
# 0
# 1  Figure 25. Relation entre le taux de pauvreté ...
# 2
# 3                                a) Taux de pauvreté
# 4
#
#                                         2  \
# 0
# 1
# 2  b) Taux d’abandon scolaire au primaire
# 3
# 4                                       c
#
#                                                    3 4
# 0                               CARTE DE LA PAUVRETE
# 1
# 2
# 3
# 4  ) Taux d’abandon scolaire au primaire et au se...
#
# Table 45:
#             0                                                  1  \
# 0           T  ableau 5. Taux d’abandon scolaire et taux de p...
# 1                                                        Abandon
# 2  Délégation
# 3                                                  primaire en %
# 4      MORNAG                                                0,2
#
#                  2                    3              4
# 0
# 1          Abandon  Abandon primaire et        Taux de
# 2
# 3  secondaire en %      secondaire en %  pauvreté en %
# 4              7,0                  3,1           11,2
#
# Table 46:
#                                                    0        1        2  \
# 0  vocation  agricole  et  rurale,  une  forte  p...
# 1                         (redoublement et abandon).
# 2  Tableau 6. Taux d’abandon  scolaire et taux de...
# 3                                                     Abandon  Abandon
# 4                                         Délégation
#
#                   3        4
# 0
# 1
# 2
# 3  Abandon primaire  Taux de
# 4
#
# Table 47:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1             Nord-Est : Nabeul, Zaghouan et Bizerte
# 2  La région du Nord connaît des taux de pauvreté...
# 3  accrue dans sa partie occidentale (voir figure...
# 4  Figure 27. Carte de la pauvreté et nombre de p...
#
# Table 48:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1  Les cartes de la figure 28 ci-après indiquent ...
# 2  Figure 28. Relation entre le taux de pauvreté ...
# 3             b) Taux d’abandon scolaire au primaire
# 4                                a) Taux de pauvreté
#
# Table 49:
#                                                    0                   1  \
# 0
# 1                                   Les  délégations  les  plus  pauvres
# 2  caractérisées  par  un  taux  d’analphabétisme...
# 3  nanties du gouvernorat de Nabeul, il s’agit de...
# 4  Figure 29. Taux de chômage, taux d’analphabéti...
#
#                                                    2                     3
# 0                                                     CARTE DE LA PAUVRETE
# 1  sont  éloignées  géographiquement  du  chef-li...                  sont
# 2
# 3
# 4
#
# Table 50:
#                                                    0           1  \
# 0
# 1  Tableau 7.Taux d’abandon scolaire et taux de p...
# 2                                                        Abandon
# 3                                         Délégation
# 4                                                     primaire %
#
#               2                 3                     4
# 0                                  CARTE DE LA PAUVRETE
# 1
# 2       Abandon  Abandon primaire               Taux de
# 3
# 4  secondaire %   et secondaire %            pauvreté %
#
# Table 51:
#                                                    0        1        2  \
# 0
# 1  Source : Calcul des auteurs à partir des donné...
# 2  Tableau 8. Taux d’abandon scolaire et taux de ...
# 3                                                     Abandon  Abandon
# 4                                         Délégation
#
#                                                    3        4
# 0  c) Taux d’abandon scolaire au primaire et au s...
# 1
# 2
# 3                                   Abandon primaire  Taux de
# 4
#
# Table 52:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1              Délégations du gouvernorat de Bizerte
# 2  Le gouvernorat de Bizerte enregistre un taux d...
# 3  Il est constitué de 13 délégations. Il est sit...
# 4  Cette situation géographique stratégique sur l...
#
# Table 53:
#                                                    0        1        2  \
# 0
# 1  Les délégations les plus pauvres sont caractér...
# 2  élevé, un taux d’analphabétisme élevé et un pr...
# 3  Tableau 9. Taux d’abandon scolaire et taux de ...
# 4                                                     Abandon  Abandon
#
#                   3                     4
# 0                    CARTE DE LA PAUVRETE
# 1
# 2
# 3
# 4  Abandon primaire               Taux de
#
# Table 54:
#     0                     1
# 0      CARTE DE LA PAUVRETE
# 1  52
#
# Table 55:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1        Nord-Ouest : Beja, Jendouba, Kef et Seliana
# 2  La région du Nord-Ouest comporte une partie re...
# 3  régions  les  plus  pauvres  se  trouvent  dan...
# 4             partie nord (voir figure 32 ci-après).
#
# Table 56:
#                                                    0           1  \
# 0  Tableau 10.Taux d’abandon scolaire et taux de ...
# 1                                                        Abandon
# 2                                         Délégation
# 3                                                     primaire %
# 4                                             AMDOUN         0,5
#
#               2                 3           4
# 0
# 1       Abandon  Abandon primaire     Taux de
# 2
# 3  secondaire %   et secondaire %  pauvreté %
# 4           7,3               3,4        37,6
#
# Table 57:
#                                                    0        1        2  \
# 0  base,  le  taux  de  chômage  élevé,  le  taux...
# 1                              tableau 14 ci-après).
# 2  Tableau 11.Taux d’abandon scolaire et taux de ...
# 3                                                     Abandon  Abandon
# 4                                         Délégation
#
#                   3                 4
# 0
# 1
# 2
# 3  Abandon primaire
# 4                    Taux de pauvreté
#
# Table 58:
#                                                   0  1  2  3  4  5  6  7  8   \
# 0
# 1  manière durable comme les ressources forestièr...
# 2  emplois et de limiter ainsi la pauvreté. Il es...
# 3  et du bois, l’exploitation de produits agricol...
# 4                                     médicinales16.
#
#   9  10 11                    12 13
# 0           CARTE DE LA PAUVRETE
# 1
# 2
# 3
# 4
#
# Table 59:
#                                                    0        1        2  \
# 0
# 1  Source : Calcul des auteurs à partir des donné...
# 2  Tableau 12.Taux d’abandon scolaire et taux de ...
# 3                                                     Abandon  Abandon
# 4                                         Délégation
#
#                                                    3        4
# 0  c) Taux d’abandon scolaire au primaire et au s...
# 1
# 2
# 3                                   Abandon primaire  Taux de
# 4
#
# Table 60:
#                                                    0                       1  \
# 0
# 1  Les cartes de la figure 36 ci-après indiquent ...
# 2  d’urbanisation, taux d’analphabétisme, taux de...
# 3  Figure 36. Relation entre le taux de pauvreté ...
# 4                                                     a) Taux d’urbanisation
#
#                           2
# 0      CARTE DE LA PAUVRETE
# 1
# 2
# 3
# 4  b) Taux d'analphabétisme
#
# Table 61:
#                                                    0                     1
# 0                                                     CARTE DE LA PAUVRETE
# 1  d'eau  et  à  la  présence  du  barrage  Mella...
# 2  périmètres irrigués,  l’élevage  des  espèces ...
# 3  forestiers  permet  de  créer  des  emplois et...
# 4  Youssef est considérée comme étant défavorisée...
#
# Table 62:
#                                                    0 1  \
# 0
# 1  Figure 37. Relation entre le taux de pauvreté ...
# 2
# 3                                a) Taux de pauvreté
# 4
#
#                                         2  \
# 0
# 1
# 2  b) Taux d’abandon scolaire au primaire
# 3
# 4
#
#                                                    3
# 0                               CARTE DE LA PAUVRETE
# 1
# 2
# 3
# 4  c) Taux d’abandon scolaire au primaire et au s...
#
# Table 63:
#                                                    0           1  \
# 0
# 1  Tableau 13.Taux d’abandon scolaire des délégat...
# 2                                                        Abandon
# 3                                         Délégation
# 4                                                     primaire %
#
#               2                 3                     4
# 0                                  CARTE DE LA PAUVRETE
# 1
# 2       Abandon  Abandon primaire               Taux de
# 3
# 4  secondaire %   et secondaire %            pauvreté %
#
# Table 64:
#     0                     1
# 0      CARTE DE LA PAUVRETE
# 1  62
#
# Table 65:
#                                                    0  \
# 0
# 1
# 2  Le Centre-Est est composé de quatre gouvernora...
# 3              de  chômage  est  de  9,9 %,  chiffre
# 4  d’entreprises employant 10 travailleurs et plu...
#
#                                                1  \
# 0
# 1  Centre-Est : Sousse, Monastir, Mahdia et Sfax
# 2
# 3                                   inférieur  à
# 4
#
#                                             2                     3
# 0                                              CARTE DE LA PAUVRETE
# 1
# 2
# 3  la  moyenne  nationale  estimée  à  15,6 %    (2015).  Le nombre
# 4
#
# Table 66:
#                                                    0  \
# 0
# 1  Le taux de chômage en 2015 était de 11,6 %, do...
# 2                                      industrielles
# 3  développement de tous les secteurs d’activité,...
# 4  entre les délégations sont importants. On obse...
#
#                                                    1  \
# 0
# 1
# 2  (10  emplois  et  plus  en  2016)  était  de  ...
# 3
# 4
#
#                                            2
# 0                       CARTE DE LA PAUVRETE
# 1
# 2  industries  exportatrices.  En  dépit  du
# 3
# 4
#
# Table 67:
#                                                    0 1 2  \
# 0
# 1  Source : Calcul des auteurs à partir des donné...
# 2  Les délégations les plus pauvres du gouvernora...
# 3              vivrière et un milieu rural dominant.
# 4  Tableau 14.Taux d’abandon scolaire et taux de ...
#
#                                                    3 4
# 0  c) Taux d’abandon scolaire au primaire et au s...
# 1
# 2
# 3
# 4
#
# Table 68:
#                                                    0 1 2                     3
# 0                                                         CARTE DE LA PAUVRETE
# 1             Délégations du gouvernorat de Monastir
# 2  Le gouvernorat de Monastir est composé de 13 d...
# 3  taux de chômage de 6,6 %, qui est largement in...
# 4  (10 emplois et plus en 2016) est de 633 entrep...
#
# Table 69:
#                                                    0 1 2 3  \
# 0
# 1  Bien  que  le  gouvernorat  de  Monastir  ait ...
# 2  confronté  à  des  défis  liés  à  la  rareté ...
# 3                                         aménagées.
# 4  Tableau 15.Taux d’abandon scolaire et taux de ...
#
#                       4
# 0  CARTE DE LA PAUVRETE
# 1
# 2
# 3
# 4
#
# Table 70:
#                                                    0           1  \
# 0  Tableau 16.Taux d’abandon scolaire et taux de ...
# 1                                                        Abandon
# 2                                         Délégation
# 3                                                     primaire %
# 4                                           CHORBANE         0,8
#
#               2                 3           4
# 0
# 1       Abandon  Abandon primaire     Taux de
# 2
# 3  secondaire %   et secondaire %  pauvreté %
# 4           5,2               2,3        36,9
#
# Table 71:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1                 Délégations du gouvernorat de Sfax
# 2  Le  gouvernorat  de  Sfax  est  situé  au  Cen...
# 3  géographique  privilégiée  sur \nle \nlittoral...
# 4  gouvernorat une métropole nationale. Le taux d...
#
# Table 72:
#                                                    0        1        2  \
# 0
# 1  Tableau 17.Taux d’abandon scolaire et taux de ...
# 2
# 3                                                     Abandon  Abandon
# 4                                         Délégation
#
#              3                     4
# 0               CARTE DE LA PAUVRETE
# 1
# 2      Abandon
# 3                            Taux de
# 4  primaire et
#
# Table 73:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1  Centre-Ouest : Kairouan, Kasserine et Sidi Bouzid
# 2  Le Centre-Ouest est l’une des régions les plus...
# 3                                      44 ci-après).
# 4  Figure 44. Carte de pauvreté et nombre de pers...
#
# Table 74:
#                                                    0           1  \
# 0                                          scolaire.
# 1  Tableau 18.Taux d’abandon scolaire et taux de ...
# 2                                                        Abandon
# 3                                         Délégation
# 4                                                     primaire %
#
#               2                 3           4
# 0
# 1
# 2       Abandon  Abandon primaire     Taux de
# 3
# 4  secondaire %   et secondaire %  pauvreté %
#
# Table 75:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1            Délégations du gouvernorat de Kasserine
# 2  Le gouvernorat de Kasserine se trouve au  Cent...
# 3  des taux de pauvreté les plus élevés du pays, ...
# 4  chômage estimé à 20,6 % (2015), supérieur au t...
#
# Table 76:
#                                                    0        1        2  \
# 0  un problème de décrochage scolaire et une faib...
# 1  Tableau 19.Taux d’abandon scolaire et taux de ...
# 2
# 3                                                     Abandon  Abandon
# 4                                         Délégation
#
#              3        4
# 0
# 1
# 2      Abandon
# 3               Taux de
# 4  primaire et
#
# Table 77:
#                                                    0    1    2    3     4
# 0                                     KASSERINE NORD  0,8  7,2  1,9  18,9
# 1  Source : Calcul des auteurs à partir des donné...
# 2          Délégations du gouvernorat de Sidi Bouzid
# 3  Le gouvernorat de Sidi Bouzid occupe une posit...
# 4  Centre-Ouest.  Il  est  composé  de  13  délég...
#
# Table 78:
#                                                    0        1        2  \
# 0  chômage  élevé,  un  fort  exode  rural,  des ...
# 1             indicateurs de qualité de vie faibles.
# 2  Tableau 20.Taux d’abandon scolaire et taux de ...
# 3
# 4                                                     Abandon  Abandon
#
#          3        4
# 0
# 1
# 2
# 3  Abandon
# 4           Taux de
#
# Table 79:
#     0                     1
# 0      CARTE DE LA PAUVRETE
# 1  76
#
# Table 80:
#                                                    0 1 2  \
# 0
# 1
# 2  La région du Sud-Est est hétérogène en termes ...
# 3  et des zones plus pauvres en zones rurales (vo...
# 4  Figure 48. Carte de pauvreté et nombre de pers...
#
#                                         3 4 5 6 7                     8 9
# 0                                                  CARTE DE LA PAUVRETE
# 1  Sud-Est : Gabes, Médenine et Tataouine
# 2
# 3
# 4
#
# Table 81:
#                                                    0        1        2  \
# 0
# 1  Source : Calcul des auteurs à partir des donné...
# 2  Tableau 21.Taux d’abandon scolaire et taux de ...
# 3                                                     Abandon  Abandon
# 4                                         Délégation
#
#                                                    3        4
# 0  c) Taux d’abandon scolaire au primaire et au s...
# 1
# 2
# 3                                   Abandon primaire  Taux de
# 4
#
# Table 82:
#                                                    0 1 2 3  \
# 0
# 1  Les  cartes  de  la  figure  50  ci-après  sou...
# 2  d’urbanisation, du taux d’analphabétisme, du t...
# 3  Figure 50. Relation entre le taux de pauvreté ...
# 4                             a) Taux d’urbanisation
#
#                     4                     5 6
# 0                      CARTE DE LA PAUVRETE
# 1
# 2
# 3
# 4  b) Taux de chômage
#
# Table 83:
#                                                    0  \
# 0
# 1                                  artisanales.  Son
# 2                                     habitants/km2.
# 3  Figure 51. Relation entre le taux de pauvreté ...
# 4
#
#                                                    1  \
# 0
# 1  taux  d'urbanisation  estimé  à  78,6 %  est  ...
# 2
# 3
# 4
#
#                                          2
# 0                     CARTE DE LA PAUVRETE
# 1  la  densité  démographique  est  de  52
# 2
# 3
# 4   b) Taux d’abandon scolaire au primaire
#
# Table 84:
# ...
# 3                                                     Abandon  Abandon
# 4                                         Délégation
#
#                   3        4
# 0
# 1
# 2
# 3  Abandon primaire  Taux de
# 4
#
# Table 89:
#                                                    0           1  \
# 0  milieu rural dominant et un niveau d’instructi...
# 1  Tableau 25.Taux d’abandon scolaire et taux de ...
# 2                                                        Abandon
# 3                                         Délégation
# 4                                                     primaire %
#
#               2                 3           4
# 0
# 1
# 2       Abandon  Abandon primaire     Taux de
# 3
# 4  secondaire %   et secondaire %  pauvreté %
#
# Table 90:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1  Kebili est un gouvernorat agricole basé essent...
# 2  Des ressources en eaux et des substances utile...
# 3  Les  délégations  de  Douz  Sud  (25,9  %)  et...
# 4  affichent aussi les taux d’abandon scolaire le...
#
# Table 91:
#                                                    0           1  \
# 0  Tableau 26.Taux d’abandon scolaire et taux de ...
# 1                                                        Abandon
# 2                                         Délégation
# 3                                                     primaire %
# 4                                           DOUZ SUD         0,1
#
#               2                 3           4
# 0
# 1       Abandon  Abandon primaire     Taux de
# 2
# 3  secondaire %   et secondaire %  pauvreté %
# 4           2,5               0,8        25,9
#
# Table 92:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1                                         Conclusion
# 2  Le  présent  rapport  révèle  des  variations ...
# 3  régions et entre celles-ci. Le Centre-Ouest et...
# 4  de  la  pauvreté  et  de  nombre  de  personne...
#
# Table 93:
#     0                     1
# 0      CARTE DE LA PAUVRETE
# 1  88
#
# Table 94:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1                                         Références
# 2  Ayadi M., Boulila G. et Lahouel M. (2005) : Pr...
# 3  in the 1990s. Lessons and Insights from 14 cou...
# 4  http://siteresources.worldbank.org/INTTUNISIAI...
#
# Table 95:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1  Parent G. et Paquin A. (1994) : Enquête auprès...
# 2  sciences de l’éducation, volume 20, numéro 4, ...
# 3  Rapport de diagnostic des gouvernorats de Kair...
# 4  œuvre par l’Union européenne et l’Organisation...
#
# Table 96:
#                                                    0
# 0  Annexe A. Liste complète des variables considé...
# 1                                  et le recensement
# 2  Tableau A1. Variables communes et comparables ...
# 3                              Composition du ménage
# 4                                   Taille du ménage
#
# Table 97:
#                                                    0        1      2  \
# 0  Annexe B. Estimations de la pauvreté par gouve...
# 1  Tableau A2. Estimation de la pauvreté par gouv...
# 2
# 3                                                     Taux de  Écart
# 4                                        Gouvernorat
#
#                                3 4        5            6           7
# 0
# 1
# 2   Enquête de consommation 2015             Recensement
# 3  Intervalle de confidence 95 %    Taux de        Écart  Différence
# 4
#
# Table 98:
#                                                    0     1           2  \
# 0
# 1  Tableau A3. Estimation de la pauvreté par délé...
# 2
# 3                                         Délégation  Code  Population
# 4
#
#           3                     4
# 0            CARTE DE LA PAUVRETE
# 1
# 2   Taux de
# 3                      Écart type
# 4  pauvreté
#
# Table 99:
#               0     1      2     3                     4
# 0                                   CARTE DE LA PAUVRETE
# 1  Douar Hicher  1452  84090  10.8                0.0087
# 2    Oued Ellil  1453  69317   8.2                0.0066
# 3     Mornaguia  1454  42687   7.8                0.0083
# 4     Borj Amri  1455  17408  12.1                0.0159
#
# Table 100:
#            0     1      2     3                     4
# 0                                CARTE DE LA PAUVRETE
# 1  Beja Nord  2151  71198    23                 0.013
# 2   Beja Sud  2152  38101  18.5                0.0133
# 3     Amdoun  2153  21187  37.6                0.0269
# 4      Nefza  2154  48101  37.5                0.0185
#
# Table 101:
#                         0     1      2     3                     4
# 0                                             CARTE DE LA PAUVRETE
# 1  Sousse Sidi Abdelhamid  3154  52787  17.7                 0.015
# 2           Hammam Sousse  3155  42691   8.5                  0.01
# 3                  Akouda  3156  34494   9.3                0.0107
# 4            Kalaâ Kebira  3157  59132  16.2                0.0136
#
# Table 102:
#             0     1      2     3                     4
# 0                                 CARTE DE LA PAUVRETE
# 1      Agareb  3457  40943  10.7                0.0109
# 2  Djebeniana  3458  49678   8.7                0.0095
# 3     El Amra  3459  30599   6.8                0.0113
# 4   El Hencha  3460  49223  11.8                0.0112
#
# Table 103:
#                0     1      2     3                     4
# 0                                    CARTE DE LA PAUVRETE
# 1       Mezzouna  4360  24766  34.3                0.0261
# 2         Regueb  4361  64998  23.7                0.0128
# 3  Ouled Haffouz  4362  19579  21.3                0.0225
# 4   Gabes Medina  5151  46731  11.1                0.0105
#
# Table 104:
#              0     1      2     3                     4
# 0                                  CARTE DE LA PAUVRETE
# 1        Nefta  6254  21731  17.3                0.0181
# 2       Hazoua  6255   4700  22.6                0.0431
# 3   Kebili Sud  6351  30447  15.8                0.0149
# 4  Kebeli Nord  6352  31854  12.3                 0.012
#
# Table 105:
#                                                    0         1           2  \
# 0                           Modèle 1 – Zones rurales
# 1  Tableau A4. Résultats de la carte de pauvreté ...
# 2                                                      Enquête
# 3                                       Gouvernorat/   Taux de  Écart-type
# 4                                             Région  pauvreté
#
#        3          4            5         6       7
# 0
# 1
# 2                    Recensement
# 3  Unité  Nombre de       Nombre   Taux de  Écart-
# 4           ménages  d’individus  pauvreté    type
#
# Table 106:
#                                                    0
# 0                               CARTE DE LA PAUVRETE
# 1  Les  zones  les  plus  pauvres  sont  concentr...
# 2  Grand Tunis présente le taux de pauvreté le pl...
# 3  Le modèle complet présentant les variables, le...
# 4  résultats de la carte de la pauvreté reflètent...
#
# Table 107:
#         0         1       2               3 4         5       6 7  \
# 0           Taux de  Écart-   Intervalle de
# 1                                               Taux de  Écart-
# 2          pauvreté    type  confiance 95 %
# 3  Région
# 4                                              pauvreté    type
#
#                 8
# 0   Intervalle de
# 1
# 2  confiance 95 %
# 3
# 4
#
# Table 108:
#                   0     1
# 0                    40 %
# 1                    35 %
# 2                    30 %
# 3                    25 %
# 4  Taux de pauvreté  20 %
#
# Table 109:
#                                                    0  \
# 0
# 1  Tableau A6. Estimation par la moindre carrée g...
# 2                                   Log des dépenses
# 3                          Ménage a une bibliothèque
# 4                       Chef de ménage à la retraite
#
#                              1          2  \
# 0  Estimation de l'ENBCNV 2015
# 1
# 2                        Coef.  Std. Err.
# 3                       0,0547     0,0170
# 4                       0,0805     0,0173
#
#                                         3       4            5          6
# 0  Estimations de la carte de la pauvreté
# 1
# 2                                       z     P>z  [95 % Conf.  Interval]
# 3                                  3,2200  0,0010       0,0214     0,0880
# 4                                  4,6700  0,0000       0,0467     0,1144
#
# Table 110:
#                             0       1       2        3       4  \
# 0
# 1        Ménage a une laveuse  0,1201  0,0105  11,4200  0,0000
# 2  Ménage a un lave-vaisselle  0,1681  0,0360   4,6700  0,0000
# 3        Ménages sans enfants  0,5474  0,0228  24,0200  0,0000
# 4          Nombre de chambres  0,0365  0,0050   7,3400  0,0000
#
#                       5       6
# 0  CARTE DE LA PAUVRETE
# 1                0,0995  0,1408
# 2                0,0975  0,2387
# 3                0,5027  0,5921
# 4                0,0268  0,0463
#
# Table 111:
#                                                    0         1      2      3  \
# 0                          Modèle 2 – Petites villes
# 1  Tableau A7. Résultats de la carte de pauvreté,...
# 2                                            Enquête
# 3                                 Gouvernorat/Région   Taux de  Écart  Unité
# 4                                                     pauvreté   type
#
#            4            5         6      7
# 0
# 1
# 2             Recensement
# 3  Nombre de       Nombre   Taux de  Écart
# 4    ménages  d’individus  pauvreté   type
#
# Table 112:
#         0         1        2               3   4         5            6  \
# 0                    Enquête                                Recensement
# 1           Taux de   Écart-   Intervalle de       Taux de       Écart-
# 2          pauvreté     type  confiance 95 %      pauvreté         type
# 3  Région
# 4                                         BI  BS
#
#                 7   8
# 0
# 1   Intervalle de
# 2  confiance 95 %
# 3
# 4              BI  BS
#
# Table 113:
#   0     1
# 0    25 %
# 1    23 %
# 2    21 %
# 3    19 %
# 4    17 %
#
# Table 114:
#                                                    0       1          2  \
# 0
# 1  Tableau A9. Estimation par moindre carrée géné...
# 2                                Log des dépenses PC   Coef.  Std. Err.
# 3                          Ménage a une bibliothèque  0,1320     0,0125
# 4                       Chef de ménage à la retraite  0,1036     0,0141
#
#          3       4                     5            6
# 0                   CARTE DE LA PAUVRETE
# 1
# 2        z     P>z           [95 % Conf.  Intervalle]
# 3  10,5500  0,0000                0,1074       0,1565
# 4   7,3500  0,0000                0,0760       0,1312
#
# Table 115:
#               0                 1      2                3          4  \
# 0  Gouvernorat/  Taux de pauvreté   E.T.            Unité  Nombre de
# 1        Région                                              ménages
# 2                                         Par gouvernorat
# 3         TUNIS             3,5 %  0,6 %              111     53 196
# 4        ARIANA             5,5 %  0,8 %              112     24 823
#
#              5         6      7
# 0       Nombre   Taux de   E.T.
# 1  d’individus  pauvreté
# 2
# 3      191 626     4,6 %  0,3 %
# 4       91 108     7,1 %  0,4 %
#
# Table 116:
#       0
# 0  10 %
# 1   9 %
# 2   8 %
# 3   7 %
# 4   6 %
#
# Table 117:
#                                                    0       1          2  \
# 0                        Estimation de l'ENBCNV 2015
# 1  Tableau A12. Estimation des moindres carrées g...
# 2                                Log des dépenses PC   Coef.  Std. Err.
# 3                          Ménage a une bibliothèque  0,1341     0,0149
# 4                       Chef de ménage à la retraite  0,1954     0,0138
#
#                                         3       4            5          6
# 0  Estimations de la carte de la pauvreté
# 1
# 2                                       z     P>z  [95 % Conf.  Interval]
# 3                                  8,9700  0,0000       0,1048     0,1634
# 4                                 14,1900  0,0000       0,1684     0,2224
#
# Table 118:
#                                   0 1        2          3        4       5  \
# 0
# 1                    Modèle Alpha :
# 2                            Residu      Coef.  Std. Err.        z     P>z
# 3           Ménage a un congélateur     0,3275     0,1230   2,6600  0,0080
# 4  Ménage a une bibliothèque _yhat2    -0,0043     0,0012  -3,4800  0,0000
#
#                       6          7
# 0  CARTE DE LA PAUVRETE
# 1
# 2           [95 % Conf.  Interval]
# 3                0,0864     0,5685
# 4               -0,0068    -0,0019
#
# Table 119:
#                               0        1 2                3 4        5  \
# 0  taille du ménage, par région
# 1                                                   Enquête
# 2                        Région
# 3                                           95 % intervalle
# 4                                Taux de                       Taux de
#
#              6 7                8
# 0
# 1  Recensement
# 2
# 3                 95 % intervalle
# 4

# %% [markdown]
# ## 3. Save Tables: Poverty & School Dropout Rates (2015)
#
# Store the tables containing poverty rates per delegation and governorate along with school dropout rates, using 2015 data from the Ministry of Education and the National Institute of Statistics (INS).

# %%
# Save tables per governorate
# We should create a map of gouvernorate name to table indices
governorate_tables = {
    "Tunis": 41,
    "Ariana": 43,
    "Ben Arous": 45,
    "Manouba": 46,
    "Nabeul": 50,
    "Zaghouan": 51,
    "Bizerte": 53,
    "Beja": 56,
    "Jendouba": 57,
    "Kef": 59,
    "Siliana": 63,
    "Sousse": 67,
    "Monastir": 69,
    "Mahdia": 70,
    "Sfax": 72,
    "Kairouan": 74,
    "Kasserine": 76,
    "Sidi Bouzid": 78,
    "Gabes": 81,
    "Medenine": 85,
    "Tataouine": 84,
    "Gafsa": 88,
    "Tozeur": 89,
    "Kebili": 91 
}
for governorate, table_index in governorate_tables.items():
    table = tables[table_index]
    output_path = f"../data/interim/poverty_{governorate.lower().replace(' ', '_')}_2015.csv"
    table.to_csv(output_path)
    print(f"Saved {governorate} table to {output_path}")
# Out:
# Saved Tunis table to ../data/interim/poverty_tunis_2015.csv
# Saved Ariana table to ../data/interim/poverty_ariana_2015.csv
# Saved Ben Arous table to ../data/interim/poverty_ben_arous_2015.csv
# Saved Manouba table to ../data/interim/poverty_manouba_2015.csv
# Saved Nabeul table to ../data/interim/poverty_nabeul_2015.csv
# Saved Zaghouan table to ../data/interim/poverty_zaghouan_2015.csv
# Saved Bizerte table to ../data/interim/poverty_bizerte_2015.csv
# Saved Beja table to ../data/interim/poverty_beja_2015.csv
# Saved Jendouba table to ../data/interim/poverty_jendouba_2015.csv
# Saved Kef table to ../data/interim/poverty_kef_2015.csv
# Saved Siliana table to ../data/interim/poverty_siliana_2015.csv
# Saved Sousse table to ../data/interim/poverty_sousse_2015.csv
# Saved Monastir table to ../data/interim/poverty_monastir_2015.csv
# Saved Mahdia table to ../data/interim/poverty_mahdia_2015.csv
# Saved Sfax table to ../data/interim/poverty_sfax_2015.csv
# Saved Kairouan table to ../data/interim/poverty_kairouan_2015.csv
# Saved Kasserine table to ../data/interim/poverty_kasserine_2015.csv
# Saved Sidi Bouzid table to ../data/interim/poverty_sidi_bouzid_2015.csv
# Saved Gabes table to ../data/interim/poverty_gabes_2015.csv
# Saved Medenine table to ../data/interim/poverty_medenine_2015.csv
# Saved Tataouine table to ../data/interim/poverty_tataouine_2015.csv
# Saved Gafsa table to ../data/interim/poverty_gafsa_2015.csv
# Saved Tozeur table to ../data/interim/poverty_tozeur_2015.csv
# Saved Kebili table to ../data/interim/poverty_kebili_2015.csv
